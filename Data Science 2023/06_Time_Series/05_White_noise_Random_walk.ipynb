# %% [markdown]
# ### **Identifying white Noise and Random Walk**

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.stats.diagnostic import acorr_ljungbox

# %% [markdown]
# **Generating white noise and random walk**

# %%
np.random.seed(0)
n = 1000

# white noise
white_noise = np.random.normal(0, 1, n)

# random walk
random_shocks = np.random.normal(0, 1, n)
random_walk = np.cumsum(random_shocks)

# %% [markdown]
# **Plotting the series**

# %%
plt.figure(figsize=(14,6))

plt.subplot(211)
plt.plot(white_noise, color='#FF914D')
plt.title('White Noise')

plt.subplot(212)
plt.plot(random_walk, color='#FF914D')
plt.title('Random Walk')

plt.tight_layout()
plt.show()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ljung-Box Test**

# %%
print(f'Ljung-Box Test for White Noise: ')
lb_test_white_noise = acorr_ljungbox(white_noise, lags=10)
print(lb_test_white_noise)



print(f'Ljung-Box Test for Random Walk: ')
lb_test_random_walk = acorr_ljungbox(random_walk, lags=10)
print(lb_test_random_walk)
# Out:
# Ljung-Box Test for White Noise:
#       lb_stat  lb_pvalue
# 1    0.681615   0.409031
# 2    0.917332   0.632126
# 3    2.697840   0.440594
# 4    4.438908   0.349853
# 5    4.519451   0.477285
# 6    4.650674   0.589331
# 7   12.826435   0.076452
# 8   13.367960   0.099801
# 9   14.025258   0.121430
# 10  14.025574   0.171828
# Ljung-Box Test for Random Walk:
#         lb_stat      lb_pvalue
# 1    977.383341  1.480364e-214
# 2   1932.637717   0.000000e+00
# 3   2866.503541   0.000000e+00
# 4   3779.090229   0.000000e+00
# 5   4670.434980   0.000000e+00
# 6   5542.988144   0.000000e+00
# 7   6395.493250   0.000000e+00
# 8   7227.265840   0.000000e+00
# 9   8038.012297   0.000000e+00
# 10  8828.660312   0.000000e+00

# %% [markdown]
# The **Ljung-Box test** is used to test whether a time series has significant autocorrelation (i.e., whether past values influence future values).
#
# * **Null Hypothesis (H₀)**: The data is independent (no autocorrelation, meaning it’s white noise).
# * **Alternative Hypothesis (H₁)**: The data has significant autocorrelation.
# 📌 **Interpreting the p-value:**
# * If p-value > 0.05 → Fail to reject H₀ → No autocorrelation (White noise) ✅
# * f p-value < 0.05 → Reject H₀ → Autocorrelation exists (Not white noise) 🚨
